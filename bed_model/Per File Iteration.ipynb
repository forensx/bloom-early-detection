# %% [markdown]
# # Iterate every file in data

# %%
import os

for subdir, dirs, files in os.walk('./data/satellite/'):
    for filename in files:
        filepath = subdir + os.sep + filename

        if filepath.endswith(".nc"):
            print (filepath)
# Out:
# ./data/satellite/requested_files_1/requested_files/A2020258175000.L2_LAC_OC.x.nc
# ./data/satellite/requested_files_1/requested_files/A2020258192500.L2_LAC_OC.x.nc
# ./data/satellite/requested_files_1/requested_files/A2020258193000.L2_LAC_OC.x.nc
# ./data/satellite/requested_files_1/requested_files/A2020259183000.L2_LAC_OC.x.nc
# ./data/satellite/requested_files_1/requested_files/A2020259183500.L2_LAC_OC.x.nc
# ./data/satellite/requested_files_1/requested_files/A2020259201000.L2_LAC_OC.x.nc
# ./data/satellite/requested_files_1/requested_files/A2020260173500.L2_LAC_OC.x.nc
# ./data/satellite/requested_files_1/requested_files/A2020260174000.L2_LAC_OC.x.nc
# ./data/satellite/requested_files_1/requested_files/A2020260191500.L2_LAC_OC.x.nc
# ./data/satellite/requested_files_1/requested_files/A2020261182000.L2_LAC_OC.x.nc
# ./data/satellite/requested_files_1/requested_files/A2020261200000.L2_LAC_OC.x.nc
# ./data/satellite/requested_files_1/requested_files/A2020262172500.L2_LAC_OC.x.nc
# ...
